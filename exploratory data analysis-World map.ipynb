# %%
import plotly.express as px
import pandas as pd

# Exploratory Data Analysis (EDA) - World Map - Total Spending Per Country in Billion Dollar
df = pd.read_csv("Global_Space_Exploration_Dataset.csv")

avg_temp = df.groupby('Country', as_index=False)['Budget (in Billion $)'].sum()
# World Map
fig = px.choropleth(
    avg_temp,
    locations='Country',
    locationmode='country names',
    color='Budget (in Billion $)',
    color_continuous_scale='RdYlBu_r',
    title='Total Spending Per Country in Billion Dollar',
)
fig.update_layout(
    title_x=0.5,
    height=600 
)
fig.show()

# %%
import plotly.express as px
import pandas as pd

# Exploratory Data Analysis (EDA) - World Map - Average Success Launch Per Country
df = pd.read_csv("Global_Space_Exploration_Dataset.csv")

avg_temp = df.groupby('Country', as_index=False)['Success Rate (%)'].mean()
# World Map
fig = px.choropleth(
    avg_temp,
    locations='Country',
    locationmode='country names',
    color='Success Rate (%)',
    color_continuous_scale='RdYlBu_r',
    title='Average Success Launch Per Country',
)
fig.update_layout(
    title_x=0.5,
    height=600 
)
fig.show()
